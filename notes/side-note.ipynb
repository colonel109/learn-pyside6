# %%
import sys

# %%
for ag in sys.argv:
    print(ag)
# Out:
# e:\learn-pyside6\.venv\Lib\site-packages\ipykernel_launcher.py
# --f="c:\Users\Nguyen Duong\AppData\Roaming\jupyter\runtime\kernel-v325149f54d9dae971046de8dbf5e687c87471ddde.json"
